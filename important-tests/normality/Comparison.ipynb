# %% [markdown]
# # Rank comparison

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import seaborn as sns

# %%
tests = ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank = [5, 3, 1, 6, 4, 2]
distribution = ["Cauchy"]*len(tests)

tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Chi-Square df=1"]*6

tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Chi-Square df=5"]*6

tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 1, 6, 4, 2]
distribution += ["Chi-Square df=20"]*6

tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Exponential"]*6

tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Gamma a=1.5"]*6

tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Gamma a=2"]*6

tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Gamma a=4"]*6

tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 1, 6, 4, 2]
distribution += ["Logistic"]*6


tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Lognormal sigma=0.5"]*6

tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Lognormal sigma=0.5"]*6


tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Lognormal sigma=1"]*6


tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Lognormal sigma=2"]*6


tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 1, 6, 4, 2]
distribution += ["t-Student df=1"]*6


tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 1, 6, 4, 2]
distribution += ["t-Student df=20"]*6

tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 1, 6, 4, 2]
distribution += ["t-Student df=5"]*6


tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [4, 2, 5, 6, 3, 1]
distribution += ["Uniform"]*6


tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Weibull c=0.5"]*6


tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Weibull c=1.5"]*6

tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 3, 2, 6, 4, 1]
distribution += ["Weibull c=2"]*6


tests += ["Abdi-Molin", "Anderson-Darling", "Filliben", "Kolmogorov-Smirnov", "Lilliefors", "Shapiro-Wilk"]
rank += [5, 2, 1, 6, 4, 3]
distribution += ["Laplace"]*6



df = pd.DataFrame({
    "Test": tests,
    "Rank": rank,
    "Distribution": distribution
})

df
# Out:
#                    Test  Rank Distribution
# 0            Abdi-Molin     5       Cauchy
# 1      Anderson-Darling     3       Cauchy
# 2              Filliben     1       Cauchy
# 3    Kolmogorov-Smirnov     6       Cauchy
# 4            Lilliefors     4       Cauchy
# ..                  ...   ...          ...
# 121    Anderson-Darling     2      Laplace
# 122            Filliben     1      Laplace
# 123  Kolmogorov-Smirnov     6      Laplace
# 124          Lilliefors     4      Laplace
# 125        Shapiro-Wilk     3      Laplace
#
# [126 rows x 3 columns]

# %%
df_result = df.groupby('Test')['Rank'].sum().sort_values()
df_result
# Out:
# Test
# Shapiro-Wilk           29
# Filliben               38
# Anderson-Darling       61
# Lilliefors             83
# Abdi-Molin            104
# Kolmogorov-Smirnov    126
# Name: Rank, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,4))
ax = df_result.plot(kind='barh', ax=ax)
ax.set_ylabel(None)
ax.set_xlabel("Ranking")
plt.show()
