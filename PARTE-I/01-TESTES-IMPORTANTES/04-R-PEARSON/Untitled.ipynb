# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
x = np.arange(10)
np.random.seed(42)
x = x + np.random.normal(0,1,10)/2
y = np.arange(10)
np.random.seed(31416)
y = y + np.random.normal(0,1,10)/2

# %%
plt.figure(figsize=(6,4))
plt.scatter(x, y)
plt.show()
