# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import sys
sys.path.insert(0, 'C:/Users/ander/Repositorios/val-metodos-analiticos/funcs')
import functions
import random

# %%
x1 = np.array([13, 7, 7, 16, 13, 16, 4, 15, 7, 13])

x1 = x1+15

x2 = np.array([12, 8, 6, 16, 12, 14, 1, 18, 4, 11])

x3 = np.array([10, 9, 7, 15, 15, 13, 3, 19, 5, 10])

x4 = np.array([14, 5, 8, 13, 17, 15, 2, 18, 5, 9])

x4 = x4 - 15

# %%
levene = stats.levene(x1, x2, x3, x4)
levene
# Out:
# LeveneResult(statistic=0.3555347091932456, pvalue=0.7854070508891482)

# %%
functions.make_f_distribution_plot(levene.statistic, levene.pvalue, gl_numerator=4-1, gl_denominator=4*x1.size - 4, alpha=0.05)

# %%
fig, ax = plt.subplots(figsize=(12,5))

ax.boxplot([x1, x2, x3, x4], vert=False)

ax.set_yticklabels(["Grupo A", "Grupo B", "Grupo C", "Grupo D", ])
# ax.set_xlim(-.5, 35)
# plt.savefig("boxplot.png", transparent=True, bbox_inches='tight')
plt.show()

# %%
x1 = np.array([13, 7, 7, 16, 13, 16, 4, 15, 7, 13])

x1 = x1+15

x2 = np.array([12, 8, 6, 16, 12, 14, 1, 18, 4, 11])

x3 = np.array([10, 9, 7, 15, 15, 13, 3, 19, 5, 10])

x3 = x3/10

x4 = np.array([14, 5, 8, 13, 17, 15, 2, 18, 5, 9])

x4 = x4 - 15

fig, ax = plt.subplots(figsize=(12,5))

ax.boxplot([x1, x2, x3, x4], vert=False)

ax.set_yticklabels(["Grupo A", "Grupo B", "Grupo C", "Grupo D", ])
# ax.set_xlim(-.5, 35)
# plt.savefig("boxplot.png", transparent=True, bbox_inches='tight')
plt.show()

# %%
levene = stats.levene(x1, x2, x3, x4)
levene
# Out:
# LeveneResult(statistic=5.776427824528207, pvalue=0.002483313787957683)

# %%
functions.make_f_distribution_plot(levene.statistic, levene.pvalue, gl_numerator=4-1, gl_denominator=4*x1.size - 4, alpha=0.05)
