# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import random
from scipy.optimize import curve_fit

# %%
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 11

# %%
x1 = np.array([13, 7, 7, 16, 13, 16, 4, 15, 7, 13])

x1 = x1+15

x2 = np.array([12, 8, 6, 16, 12, 14, 1, 18, 4, 11])

x3 = np.array([10, 9, 7, 15, 15, 13, 3, 19, 5, 10])

x4 = np.array([14, 5, 8, 13, 17, 15, 2, 18, 5, 9])

x4 = x4 - 15

fig, ax = plt.subplots(figsize=(12,5))

ax.boxplot([x1, x2, x3, x4], vert=False)

ax.set_yticklabels(["Grupo A", "Grupo B", "Grupo C", "Grupo D", ])
# ax.set_xlim(-.5, 35)
plt.savefig("boxplot.png", transparent=True, bbox_inches='tight')
plt.show()

# %%
x1 = np.array([13, 7, 7, 16, 13, 16, 4, 15, 7, 13])

x1 = x1+15

x2 = np.array([12, 8, 6, 16, 12, 14, 1, 18, 4, 11])

x3 = np.array([10, 9, 7, 15, 15, 13, 3, 19, 5, 10])

x3 = x3/10

x4 = np.array([14, 5, 8, 13, 17, 15, 2, 18, 5, 9])

x4 = x4 - 15

fig, ax = plt.subplots(figsize=(12,5))

ax.boxplot([x1, x2, x3, x4], vert=False)

ax.set_yticklabels(["Grupo A", "Grupo B", "Grupo C", "Grupo D", ])
# ax.set_xlim(-.5, 35)
plt.savefig("boxplot.png", transparent=True, bbox_inches='tight')
plt.show()

# %%
x1 = np.array([20, 32, 2, 5, 5, 18, 21, 7, 28, 40])

x2 = np.array([12, 8, 6, 16, 12, 14, 1, 18, 4, 11])

x3 = np.array([10, 9, 7, 15, 15, 13, 3, 19, 5, 10])

x4 = np.array([14, 5, 8, 13, 17, 15, 2, 18, 5, 9])

fig, ax = plt.subplots(figsize=(7,5))

ax.boxplot([x1, x2, x3, x4], )

ax.set_xticklabels(["Grupo A", "Grupo B", "Grupo C", "Grupo D", ])
plt.show()
