# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()
ax.bar(["A", "B - A", "B"], [4, 3, 7], color=["gray", "salmon", "lightgray"], width=.8, bottom=[0, 4, 0])
ax.spines[['top', 'right', 'left']].set_visible(False)
ax.set_yticks([])
ax.set_ylim(0,10)

plt.show()
